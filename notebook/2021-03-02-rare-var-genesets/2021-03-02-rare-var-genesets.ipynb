# %% [markdown]
# Testing enrichment for genesets in the rare variant paper Nature. 2014 Feb 13; 506(7487): 185–190.

# %%
## point the kernel to a new working directory
import sys
import os
sys.path.insert(1, "/mnt/c/Users/emaur/Dropbox (MIT)/Walsh Lab/SCZ_SNV/bsm/src/")
os.chdir("/mnt/c/Users/emaur/Dropbox (MIT)/Walsh Lab/SCZ_SNV/bsm/")

# %%
os.environ["PYTHONPATH"] = "/mnt/c/Users/emaur/Dropbox (MIT)/Walsh Lab/SCZ_SNV/bsm/"

# %%
! echo $PYTHONPATH
# Out:
# /mnt/c/Users/emaur/Dropbox (MIT)/Walsh Lab/SCZ_SNV/bsm/

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
from bsmcalls import SNPnexus
from bsmcalls import operations
from bsmcalls import preprocessing
from matplotlib import pyplot as plt
import attila_utils
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-f2e3f4fca4de> in <module>
#       6 import seaborn as sns
#       7 import scipy.stats as stats
# ----> 8 from bsmcalls import SNPnexus
#       9 from bsmcalls import operations
#      10 from bsmcalls import preprocessing
#
# /mnt/c/Users/emaur/Dropbox (MIT)/Walsh Lab/SCZ_SNV/bsm/src/bsmcalls/SNPnexus.py in <module>
#       9 import ensembl_rest
#      10 import pickle
# ---> 11 from bsmcalls import individuals
#      12 import bsmutils
#      13
#
# /mnt/c/Users/emaur/Dropbox (MIT)/Walsh Lab/SCZ_SNV/bsm/src/bsmcalls/individuals.py in <module>
#      35     return(clinical)
#      36
# ---> 37 def read_walsh_clinical(clin=read_clinical(), indIDs=np.loadtxt(walsh_vcfs_path, dtype=str)[:, 0]):
#      38     '''
# ...

# %%
data = SNPnexus.load_data('../../results/2020-09-07-annotations/annotated-calls.p')

# %%
fpath = '../../resources/rare-variants/41586_2014_BFnature12975_MOESM71_ESM.csv'
genesets = pd.read_csv(fpath, sep='\t', index_col='Gene symbol').dropna().astype(pd.CategoricalDtype())
genesets = genesets.apply(lambda s: s.cat.rename_categories({'.': False, 'Y': True}), axis=1)
genesets['composite'] = True
genesets
# Out:
#                PSD FMRP-target SCZ de novo  Calcium channel  composite
# Gene symbol
# AAK1         False        True        False           False       True
# AARS          True       False        False           False       True
# AATK         False        True        False           False       True
# ABCA2        False        True        False           False       True
# ABCA3        False        True        False           False       True
# ...            ...         ...          ...             ...        ...
# ZNF721       False       False         True           False       True
# ZNF77        False       False         True           False       True
# ZNFX1        False        True        False           False       True
# ZP4          False       False         True           False       True
# ZYG11B       False        True        False           False       True
#
# [1796 rows x 5 columns]

# %%
genesetsd = {c: set(genesets.index[genesets[c]]) for c in genesets}
querydict = {'near_gens_Annotation': ['coding nonsyn', 'coding syn', 'missense', 'stop-gain', 'intronic (splice_site)'],
             'near_gens_Overlapped Gene': genesetsd,
            }

operations.get_summary(data, querydict)
# Out:
# /home/attila/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# /home/attila/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:6125: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp
#                                                   Control  SCZ  ASD  All  \
# Feature                   Query
# near_gens_Annotation      coding nonsyn                23   43   23   89
#                           coding syn                   16   20   15   51
#                           missense                      0    0    0    0
#                           stop-gain                     1    0    0    1
#                           intronic (splice_site)        0    1    0    1
# ...

# %%
operations.get_summary(preprocessing.drop_category(data, 'ASD'), querydict)
# Out:
# /home/attila/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# /home/attila/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:6125: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp
#                                                   Control  SCZ  All  \
# Feature                   Query
# near_gens_Annotation      coding nonsyn                23   43   66
#                           coding syn                   16   20   36
#                           missense                      0    0    0
#                           stop-gain                     1    0    1
#                           intronic (splice_site)        0    1    1
# near_gens_Overlapped Gene PSD                          42   70  112
# ...

# %%
# %connect_info
# Out:
# {
#   "shell_port": 55207,
#   "iopub_port": 50653,
#   "stdin_port": 60943,
#   "control_port": 59807,
#   "hb_port": 36907,
#   "ip": "127.0.0.1",
#   "key": "a51cfaba-2d591736ff64c126a9f29be5",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-4a56d15f-5b5f-41bf-84e5-63b792609539.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
